# %% [markdown]
# <a href="https://colab.research.google.com/github/chiggyene/Learning-data-sceince-with-python/blob/main/Exercise.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

# %%
df=pd.read_csv("50000 Sales Records.csv")
df
# Out:
#                                   Region             Country        Item Type  \
# 0                     Sub-Saharan Africa             Namibia        Household
# 1                                 Europe             Iceland        Baby Food
# 2                                 Europe              Russia             Meat
# 3                                 Europe            Moldova              Meat
# 4                                 Europe               Malta           Cereal
# ...                                  ...                 ...              ...
# 49995  Central America and the Caribbean  Dominican Republic        Baby Food
# 49996  Central America and the Caribbean                Cuba  Office Supplies
# 49997                               Asia             Vietnam    Personal Care
# 49998                 Sub-Saharan Africa        Sierra Leone          Clothes
# 49999                 Sub-Saharan Africa             Eritrea       Vegetables
#
# ...

# %% [markdown]
# # New Section

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 50000 entries, 0 to 49999
# Data columns (total 14 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Region          50000 non-null  object
#  1   Country         50000 non-null  object
#  2   Item Type       50000 non-null  object
#  3   Sales Channel   50000 non-null  object
#  4   Order Priority  50000 non-null  object
#  5   Order Date      50000 non-null  object
#  6   Order ID        50000 non-null  int64
#  7   Ship Date       50000 non-null  object
#  8   Units Sold      50000 non-null  int64
#  9   Unit Price      50000 non-null  float64
#  10  Unit Cost       50000 non-null  float64
#  11  Total Revenue   50000 non-null  float64
#  12  Total Cost      50000 non-null  float64
#  13  Total Profit    50000 non-null  float64
# dtypes: float64(5), int64(2), object(7)
# memory usage: 5.3+ MB

# %%
df.shape
# Out:
# (50000, 14)

# %%
df.columns
# Out:
# Index(['Region', 'Country', 'Item Type', 'Sales Channel', 'Order Priority',
#        'Order Date', 'Order ID', 'Ship Date', 'Units Sold', 'Unit Price',
#        'Unit Cost', 'Total Revenue', 'Total Cost', 'Total Profit'],
#       dtype='object')

# %%
df.describe()
# Out:
#            Order ID   Units Sold    Unit Price     Unit Cost  Total Revenue  \
# count  5.000000e+04  50000.00000  50000.000000  50000.000000   5.000000e+04
# mean   5.497330e+08   4999.61898    265.651350    187.322482   1.323716e+06
# std    2.609179e+08   2884.33508    216.916752    175.580570   1.463891e+06
# min    1.000132e+08      1.00000      9.330000      6.920000   2.799000e+01
# 25%    3.240070e+08   2498.00000     81.730000     35.840000   2.764871e+05
# 50%    5.504224e+08   5017.50000    154.060000     97.440000   7.813247e+05
# 75%    7.767824e+08   7493.25000    421.890000    263.330000   1.808642e+06
# max    9.999995e+08  10000.00000    668.270000    524.960000   6.682032e+06
#
#          Total Cost  Total Profit
# count  5.000000e+04  5.000000e+04
# mean   9.331574e+05  3.905587e+05
# std    1.145548e+06  3.777588e+05
# min    2.076000e+01  7.230000e+00
# 25%    1.606370e+05  9.415092e+04
# 50%    4.671040e+05  2.795364e+05
# 75%    1.190390e+06  5.642867e+05
# ...

# %%
df.isna()
# Out:
#        Region  Country  Item Type  Sales Channel  Order Priority  Order Date  \
# 0       False    False      False          False           False       False
# 1       False    False      False          False           False       False
# 2       False    False      False          False           False       False
# 3       False    False      False          False           False       False
# 4       False    False      False          False           False       False
# ...       ...      ...        ...            ...             ...         ...
# 49995   False    False      False          False           False       False
# 49996   False    False      False          False           False       False
# 49997   False    False      False          False           False       False
# 49998   False    False      False          False           False       False
# 49999   False    False      False          False           False       False
#
# ...

# %%
df.isna().sum()  #To know missing cells (sum)
# Out:
# Region            0
# Country           0
# Item Type         0
# Sales Channel     0
# Order Priority    0
# Order Date        0
# Order ID          0
# Ship Date         0
# Units Sold        0
# Unit Price        0
# Unit Cost         0
# Total Revenue     0
# Total Cost        0
# Total Profit      0
# dtype: int64

# %%
df.head(10)
# Out:
#                Region    Country  Item Type Sales Channel Order Priority  \
# 0  Sub-Saharan Africa    Namibia  Household       Offline              M
# 1              Europe    Iceland  Baby Food        Online              H
# 2              Europe     Russia       Meat        Online              L
# 3              Europe   Moldova        Meat        Online              L
# 4              Europe      Malta     Cereal        Online              M
# 5                Asia  Indonesia       Meat        Online              H
# 6  Sub-Saharan Africa   Djibouti  Household        Online              M
# 7              Europe     Greece  Household        Online              L
# 8  Sub-Saharan Africa   Cameroon  Cosmetics       Offline              M
# 9  Sub-Saharan Africa    Nigeria  Cosmetics        Online              C
#
#    Order Date   Order ID   Ship Date  Units Sold  Unit Price  Unit Cost  \
# 0   8/31/2015  897751939  10/12/2015        3604      668.27     502.54
# ...

# %% [markdown]
# Handling Missing Values/Cells

# %%
bg = df.copy(deep=True)  #copy my dataframe
bg
# Out:
#                                   Region             Country        Item Type  \
# 0                     Sub-Saharan Africa             Namibia        Household
# 1                                 Europe             Iceland        Baby Food
# 2                                 Europe              Russia             Meat
# 3                                 Europe            Moldova              Meat
# 4                                 Europe               Malta           Cereal
# ...                                  ...                 ...              ...
# 49995  Central America and the Caribbean  Dominican Republic        Baby Food
# 49996  Central America and the Caribbean                Cuba  Office Supplies
# 49997                               Asia             Vietnam    Personal Care
# 49998                 Sub-Saharan Africa        Sierra Leone          Clothes
# 49999                 Sub-Saharan Africa             Eritrea       Vegetables
#
# ...

# %%
#replace missing values with zero
drop_missing_values = bg.fillna(0)

# %%
drop_missing_values.isna().sum()
# Out:
# Region            0
# Country           0
# Item Type         0
# Sales Channel     0
# Order Priority    0
# Order Date        0
# Order ID          0
# Ship Date         0
# Units Sold        0
# Unit Price        0
# Unit Cost         0
# Total Revenue     0
# Total Cost        0
# Total Profit      0
# dtype: int64

# %%
drop_missing_values
# Out:
#                                   Region             Country        Item Type  \
# 0                     Sub-Saharan Africa             Namibia        Household
# 1                                 Europe             Iceland        Baby Food
# 2                                 Europe              Russia             Meat
# 3                                 Europe            Moldova              Meat
# 4                                 Europe               Malta           Cereal
# ...                                  ...                 ...              ...
# 49995  Central America and the Caribbean  Dominican Republic        Baby Food
# 49996  Central America and the Caribbean                Cuba  Office Supplies
# 49997                               Asia             Vietnam    Personal Care
# 49998                 Sub-Saharan Africa        Sierra Leone          Clothes
# 49999                 Sub-Saharan Africa             Eritrea       Vegetables
#
# ...

# %%
drop_missing_values2 = bg.dropna()
drop_missing_values2
# Out:
#                                   Region             Country        Item Type  \
# 0                     Sub-Saharan Africa             Namibia        Household
# 1                                 Europe             Iceland        Baby Food
# 2                                 Europe              Russia             Meat
# 3                                 Europe            Moldova              Meat
# 4                                 Europe               Malta           Cereal
# ...                                  ...                 ...              ...
# 49995  Central America and the Caribbean  Dominican Republic        Baby Food
# 49996  Central America and the Caribbean                Cuba  Office Supplies
# 49997                               Asia             Vietnam    Personal Care
# 49998                 Sub-Saharan Africa        Sierra Leone          Clothes
# 49999                 Sub-Saharan Africa             Eritrea       Vegetables
#
# ...

# %%
drop_missing_values2.isna().sum()
# Out:
# Region            0
# Country           0
# Item Type         0
# Sales Channel     0
# Order Priority    0
# Order Date        0
# Order ID          0
# Ship Date         0
# Units Sold        0
# Unit Price        0
# Unit Cost         0
# Total Revenue     0
# Total Cost        0
# Total Profit      0
# dtype: int64

# %%
drop_missing_values2.columns
# Out:
# Index(['Region', 'Country', 'Item Type', 'Sales Channel', 'Order Priority',
#        'Order Date', 'Order ID', 'Ship Date', 'Units Sold', 'Unit Price',
#        'Unit Cost', 'Total Revenue', 'Total Cost', 'Total Profit'],
#       dtype='object')

# %%
drop_missing_values2.shape
# Out:
# (50000, 14)

# %% [markdown]
# Building  Machine Learning Model

# %%
drop_missing_values.shape
# Out:
# (50000, 14)

# %%
drop_missing_values.columns
# Out:
# Index(['Region', 'Country', 'Item Type', 'Sales Channel', 'Order Priority',
#        'Order Date', 'Order ID', 'Ship Date', 'Units Sold', 'Unit Price',
#        'Unit Cost', 'Total Revenue', 'Total Cost', 'Total Profit'],
#       dtype='object')

# %%
melb_data.rename(columns={'Unit Price': 'Price'}, inplace=True)

# %%
melb_data = drop_missing_values2 #change of variable name for easy identification
melb_data
# Out:
#                                   Region             Country        Item Type  \
# 0                     Sub-Saharan Africa             Namibia        Household
# 1                                 Europe             Iceland        Baby Food
# 2                                 Europe              Russia             Meat
# 3                                 Europe            Moldova              Meat
# 4                                 Europe               Malta           Cereal
# ...                                  ...                 ...              ...
# 49995  Central America and the Caribbean  Dominican Republic        Baby Food
# 49996  Central America and the Caribbean                Cuba  Office Supplies
# 49997                               Asia             Vietnam    Personal Care
# 49998                 Sub-Saharan Africa        Sierra Leone          Clothes
# 49999                 Sub-Saharan Africa             Eritrea       Vegetables
#
# ...

# %%
y = melb_data.Price
y  #This is my target variable  -what i want to predict
# Out:
# 0        668.27
# 1        255.28
# 2        421.89
# 3        421.89
# 4        205.70
#           ...
# 49995    255.28
# 49996    651.21
# 49997     81.73
# 49998    109.28
# 49999    154.06
# Name: Price, Length: 50000, dtype: float64

# %%
melb_data.columns
# Out:
# Index(['Region', 'Country', 'Item Type', 'Sales Channel', 'Order Priority',
#        'Order Date', 'Order ID', 'Ship Date', 'Units Sold', 'Price',
#        'Unit Cost', 'Total Revenue', 'Total Cost', 'Total Profit'],
#       dtype='object')

# %%
melb_features = ['Price', 'Item Type']   #a list in a variable
print(melb_features)
# Out:
# ['Price', 'Item Type']

# %%
X = melb_data[melb_features]
X
# Out:
#         Price        Item Type
# 0      668.27        Household
# 1      255.28        Baby Food
# 2      421.89             Meat
# 3      421.89             Meat
# 4      205.70           Cereal
# ...       ...              ...
# 49995  255.28        Baby Food
# 49996  651.21  Office Supplies
# 49997   81.73    Personal Care
# 49998  109.28          Clothes
# 49999  154.06       Vegetables
#
# [50000 rows x 2 columns]

# %%
X.describe()
# Out:
#               Price
# count  50000.000000
# mean     265.651350
# std      216.916752
# min        9.330000
# 25%       81.730000
# 50%      154.060000
# 75%      421.890000
# max      668.270000

# %%
X.head()
# Out:
#     Price  Item Type
# 0  668.27  Household
# 1  255.28  Baby Food
# 2  421.89       Meat
# 3  421.89       Meat
# 4  205.70     Cereal

# %%
labels = ['Price', 'Item Type']

# %%
columns = labels

# %% [markdown]
# Using Scikit Learn for ML Modeling

# %%
from sklearn.tree import DecisionTreeRegressor

#Define model. Specify a number for random_state to ensure same results each run
melb_model = DecisionTreeRegressor(random_state=1)   #DecisionTreeRegressor

melb_model.fit(X,y)

DecisionTreeRegressor(random_state=1)

# %%
melb_model.predict(X.head())

# %%
print('Making prdictions for 5houses:')
print(X.head())
print('the prediction are')
print(melb_model.predict(X.head()))
print('My ML Model:)')

# %% [markdown]
# Model Evaluation -MEA

# %%
from sklearn.metrics import mean_absolute_error

predicted_house_prices = melb_model.predict(X)
mean_absolute_error(y, predicted_house_prices)

# %%
from sklearn.model_selection import train_test_split

# %%
train_X, val_X, train_y, val_y = train_test_split(X, y, random_state = 1)

#Define model
melb_model = DecisionTreeRegressor(random_state=1)

#Fit model
melb_model.fit(train_X, train_y)

# %%
val_predictions = melb_model.predict(val_X)
print(mean_absolute_error(val_y, val_predictions))

# %% [markdown]
# Data Visualization

# %%
import seaborn as sns
import matplotlib.pyplot as plt
import matplotlib as mpl
import numpy as np

# Inline backend
# %matplotlib inline
mpl.style.use(['ggplot'])
import warnings
warnings.filterwarnings('ignore')

# %%
df.columns
# Out:
# Index(['Region', 'Country', 'Item Type', 'Sales Channel', 'Order Priority',
#        'Order Date', 'Order ID', 'Ship Date', 'Units Sold', 'Unit Price',
#        'Unit Cost', 'Total Revenue', 'Total Cost', 'Total Profit'],
#       dtype='object')

# %%
sns.countplot(df['Unit Price'])
# Out:
# <Axes: ylabel='count'>

# %%
df.head()

# %%
df.plot(kind='line', figsize=(14, 8))

plt.title('price')
plt.xlabel('Title')

plt.show()

# %%
df.plot  (kind="hist")

# %%
df.plot (kind="area")
