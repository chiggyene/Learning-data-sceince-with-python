# %%
#Name: Chiagozie Ene
#Group: Sales/Accounting

# %%
#!wget https://drive.google.com/file/d/1qSH3MQ1qv1XL3HL1FxcyQpTjuZy0h6RQ/view?usp=sharing
# Out:
# --2022-02-23 22:00:50--  https://drive.google.com/file/d/1qSH3MQ1qv1XL3HL1FxcyQpTjuZy0h6RQ/view?usp=sharing
# Resolving drive.google.com (drive.google.com)... 173.194.216.101, 173.194.216.113, 173.194.216.138, ...
# Connecting to drive.google.com (drive.google.com)|173.194.216.101|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: unspecified [text/html]
# Saving to: ‘view?usp=sharing.1’
#
# view?usp=sharing.1      [ <=>                ]  62.97K  --.-KB/s    in 0.001s
#
# 2022-02-23 22:00:50 (41.6 MB/s) - ‘view?usp=sharing.1’ saved [64482]

# %%
#!unzip raw_sales.csv.zip
# Out:
# Archive:  raw_sales.csv.zip
# replace raw_sales.csv? [y]es, [n]o, [A]ll, [N]one, [r]ename: y
#   inflating: raw_sales.csv

# %%
import pandas as pd

# %%
df=pd.read_csv("500000 Sales Records.csv")
df
# Out:
#                                   Region  ... Total Profit
# 0                     Sub-Saharan Africa  ...    597290.92
# 1                                 Europe  ...    808579.10
# 2                                 Europe  ...    277305.60
# 3                                 Europe  ...    413270.00
# 4                                 Europe  ...    174965.25
# ...                                  ...  ...          ...
# 49995  Central America and the Caribbean  ...    524354.20
# 49996  Central America and the Caribbean  ...    732628.75
# 49997                               Asia  ...     42050.68
# 49998                 Sub-Saharan Africa  ...    353980.80
# 49999                 Sub-Saharan Africa  ...    251446.79
#
# [50000 rows x 14 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 50000 entries, 0 to 49999
# Data columns (total 14 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Region          50000 non-null  object
#  1   Country         50000 non-null  object
#  2   Item Type       50000 non-null  object
#  3   Sales Channel   50000 non-null  object
#  4   Order Priority  50000 non-null  object
#  5   Order Date      50000 non-null  object
#  6   Order ID        50000 non-null  int64
#  7   Ship Date       50000 non-null  object
#  8   Units Sold      50000 non-null  int64
#  9   Price           50000 non-null  float64
#  10  Unit Cost       50000 non-null  float64
#  11  Total Revenue   50000 non-null  float64
#  12  Total Cost      50000 non-null  float64
#  13  Total Profit    50000 non-null  float64
# dtypes: float64(5), int64(2), object(7)
# memory usage: 5.3+ MB

# %%
df.shape
# Out:
# (50000, 14)

# %%
df.Price.mean()
# Out:
# 265.65135019997285

# %%
df.columns
# Out:
# Index(['Region', 'Country', 'Item Type', 'Sales Channel', 'Order Priority',
#        'Order Date', 'Order ID', 'Ship Date', 'Units Sold', 'Price',
#        'Unit Cost', 'Total Revenue', 'Total Cost', 'Total Profit'],
#       dtype='object')

# %%
df.describe()
# Out:
#            Order ID   Units Sold  ...    Total Cost  Total Profit
# count  5.000000e+04  50000.00000  ...  5.000000e+04  5.000000e+04
# mean   5.497330e+08   4999.61898  ...  9.331574e+05  3.905587e+05
# std    2.609179e+08   2884.33508  ...  1.145548e+06  3.777588e+05
# min    1.000132e+08      1.00000  ...  2.076000e+01  7.230000e+00
# 25%    3.240070e+08   2498.00000  ...  1.606370e+05  9.415092e+04
# 50%    5.504224e+08   5017.50000  ...  4.671040e+05  2.795364e+05
# 75%    7.767824e+08   7493.25000  ...  1.190390e+06  5.642867e+05
# max    9.999995e+08  10000.00000  ...  5.249075e+06  1.738178e+06
#
# [8 rows x 7 columns]

# %%
df.isna()
# Out:
#        Region  Country  Item Type  ...  Total Revenue  Total Cost  Total Profit
# 0       False    False      False  ...          False       False         False
# 1       False    False      False  ...          False       False         False
# 2       False    False      False  ...          False       False         False
# 3       False    False      False  ...          False       False         False
# 4       False    False      False  ...          False       False         False
# ...       ...      ...        ...  ...            ...         ...           ...
# 49995   False    False      False  ...          False       False         False
# 49996   False    False      False  ...          False       False         False
# 49997   False    False      False  ...          False       False         False
# 49998   False    False      False  ...          False       False         False
# 49999   False    False      False  ...          False       False         False
#
# [50000 rows x 14 columns]

# %%
df.isna().sum()  #To know missing cells (sum)
# Out:
# Region            0
# Country           0
# Item Type         0
# Sales Channel     0
# Order Priority    0
# Order Date        0
# Order ID          0
# Ship Date         0
# Units Sold        0
# Price             0
# Unit Cost         0
# Total Revenue     0
# Total Cost        0
# Total Profit      0
# dtype: int64

# %%
df.head(10)
# Out:
#                Region    Country  ...  Total Cost Total Profit
# 0  Sub-Saharan Africa    Namibia  ...  1811154.16    597290.92
# 1              Europe    Iceland  ...  1344707.70    808579.10
# 2              Europe     Russia  ...  1768017.12    277305.60
# 3              Europe   Moldova   ...  2634885.25    413270.00
# 4              Europe      Malta  ...   231292.25    174965.25
# 5                Asia  Indonesia  ...   927041.98    145402.40
# 6  Sub-Saharan Africa   Djibouti  ...  2210170.92    728880.54
# 7              Europe     Greece  ...    24624.46      8120.77
# 8  Sub-Saharan Africa   Cameroon  ...  1061483.23    700869.97
# 9  Sub-Saharan Africa    Nigeria  ...  2083203.63   1375485.57
#
# [10 rows x 14 columns]

# %% [markdown]
# Handling Missing Values/Cells

# %%
bg = df.copy(deep=True)  #copy my dataframe
bg
# Out:
#                                   Region  ... Total Profit
# 0                     Sub-Saharan Africa  ...    597290.92
# 1                                 Europe  ...    808579.10
# 2                                 Europe  ...    277305.60
# 3                                 Europe  ...    413270.00
# 4                                 Europe  ...    174965.25
# ...                                  ...  ...          ...
# 49995  Central America and the Caribbean  ...    524354.20
# 49996  Central America and the Caribbean  ...    732628.75
# 49997                               Asia  ...     42050.68
# 49998                 Sub-Saharan Africa  ...    353980.80
# 49999                 Sub-Saharan Africa  ...    251446.79
#
# [50000 rows x 14 columns]

# %%
#replace missing values with zero
drop_missing_values = bg.fillna(0)

# %%
drop_missing_values.isna().sum()
# Out:
# Region            0
# Country           0
# Item Type         0
# Sales Channel     0
# Order Priority    0
# Order Date        0
# Order ID          0
# Ship Date         0
# Units Sold        0
# Price             0
# Unit Cost         0
# Total Revenue     0
# Total Cost        0
# Total Profit      0
# dtype: int64

# %%
drop_missing_values
# Out:
#                                   Region  ... Total Profit
# 0                     Sub-Saharan Africa  ...    597290.92
# 1                                 Europe  ...    808579.10
# 2                                 Europe  ...    277305.60
# 3                                 Europe  ...    413270.00
# 4                                 Europe  ...    174965.25
# ...                                  ...  ...          ...
# 49995  Central America and the Caribbean  ...    524354.20
# 49996  Central America and the Caribbean  ...    732628.75
# 49997                               Asia  ...     42050.68
# 49998                 Sub-Saharan Africa  ...    353980.80
# 49999                 Sub-Saharan Africa  ...    251446.79
#
# [50000 rows x 14 columns]

# %%
drop_missing_values2 = bg.dropna()
drop_missing_values2
# Out:
#                                   Region  ... Total Profit
# 0                     Sub-Saharan Africa  ...    597290.92
# 1                                 Europe  ...    808579.10
# 2                                 Europe  ...    277305.60
# 3                                 Europe  ...    413270.00
# 4                                 Europe  ...    174965.25
# ...                                  ...  ...          ...
# 49995  Central America and the Caribbean  ...    524354.20
# 49996  Central America and the Caribbean  ...    732628.75
# 49997                               Asia  ...     42050.68
# 49998                 Sub-Saharan Africa  ...    353980.80
# 49999                 Sub-Saharan Africa  ...    251446.79
#
# [50000 rows x 14 columns]

# %%
drop_missing_values2.isna().sum()
# Out:
# Region            0
# Country           0
# Item Type         0
# Sales Channel     0
# Order Priority    0
# Order Date        0
# Order ID          0
# Ship Date         0
# Units Sold        0
# Price             0
# Unit Cost         0
# Total Revenue     0
# Total Cost        0
# Total Profit      0
# dtype: int64

# %%
drop_missing_values2.columns
# Out:
# Index(['Region', 'Country', 'Item Type', 'Sales Channel', 'Order Priority',
#        'Order Date', 'Order ID', 'Ship Date', 'Units Sold', 'Price',
#        'Unit Cost', 'Total Revenue', 'Total Cost', 'Total Profit'],
#       dtype='object')

# %%
drop_missing_values2.shape
# Out:
# (50000, 14)

# %% [markdown]
# Building  Machine Learning Model

# %%
drop_missing_values.shape
# Out:
# (50000, 14)

# %%
drop_missing_values.columns
# Out:
# Index(['Region', 'Country', 'Item Type', 'Sales Channel', 'Order Priority',
#        'Order Date', 'Order ID', 'Ship Date', 'Units Sold', 'Price',
#        'Unit Cost', 'Total Revenue', 'Total Cost', 'Total Profit'],
#       dtype='object')

# %%
melb_data = drop_missing_values2 #change of variable name for easy identification
melb_data
# Out:
#                                   Region  ... Total Profit
# 0                     Sub-Saharan Africa  ...    597290.92
# 1                                 Europe  ...    808579.10
# 2                                 Europe  ...    277305.60
# 3                                 Europe  ...    413270.00
# 4                                 Europe  ...    174965.25
# ...                                  ...  ...          ...
# 49995  Central America and the Caribbean  ...    524354.20
# 49996  Central America and the Caribbean  ...    732628.75
# 49997                               Asia  ...     42050.68
# 49998                 Sub-Saharan Africa  ...    353980.80
# 49999                 Sub-Saharan Africa  ...    251446.79
#
# [50000 rows x 14 columns]

# %%
y = melb_data.Price
y  #This is my target variable  -what i want to predict
# Out:
# 0        668.27
# 1        255.28
# 2        421.89
# 3        421.89
# 4        205.70
#           ...
# 49995    255.28
# 49996    651.21
# 49997     81.73
# 49998    109.28
# 49999    154.06
# Name: Price, Length: 50000, dtype: float64

# %%
melb_data.columns
# Out:
# Index(['Region', 'Country', 'Item Type', 'Sales Channel', 'Order Priority',
#        'Order Date', 'Order ID', 'Ship Date', 'Units Sold', 'Price',
#        'Unit Cost', 'Total Revenue', 'Total Cost', 'Total Profit'],
#       dtype='object')

# %%
melb_features = ['Price', 'Units Sold', 'Total Revenue', 'Total Profit']   #a list in a variable
print(melb_features)
# Out:
# ['Price', 'Units Sold', 'Total Revenue', 'Total Profit']

# %%
X = melb_data[melb_features]
X
# Out:
#         Price  Units Sold  Total Revenue  Total Profit
# 0      668.27        3604     2408445.08     597290.92
# 1      255.28        8435     2153286.80     808579.10
# 2      421.89        4848     2045322.72     277305.60
# 3      421.89        7225     3048155.25     413270.00
# 4      205.70        1975      406257.50     174965.25
# ...       ...         ...            ...           ...
# 49995  255.28        5470     1396381.60     524354.20
# 49996  651.21        5803     3778971.63     732628.75
# 49997   81.73        1678      137142.94      42050.68
# 49998  109.28        4820      526729.60     353980.80
# 49999  154.06        3983      613620.98     251446.79
#
# [50000 rows x 4 columns]

# %%
X.describe()
# Out:
#               Price   Units Sold  Total Revenue  Total Profit
# count  50000.000000  50000.00000   5.000000e+04  5.000000e+04
# mean     265.651350   4999.61898   1.323716e+06  3.905587e+05
# std      216.916752   2884.33508   1.463891e+06  3.777588e+05
# min        9.330000      1.00000   2.799000e+01  7.230000e+00
# 25%       81.730000   2498.00000   2.764871e+05  9.415092e+04
# 50%      154.060000   5017.50000   7.813247e+05  2.795364e+05
# 75%      421.890000   7493.25000   1.808642e+06  5.642867e+05
# max      668.270000  10000.00000   6.682032e+06  1.738178e+06

# %%
X.head()
# Out:
#    Item Type   Price  Units Sold  Total Revenue  Total Profit
# 0  Household  668.27        3604     2408445.08     597290.92
# 1  Baby Food  255.28        8435     2153286.80     808579.10
# 2       Meat  421.89        4848     2045322.72     277305.60
# 3       Meat  421.89        7225     3048155.25     413270.00
# 4     Cereal  205.70        1975      406257.50     174965.25

# %%
labels = ['Item Type', 'Price', 'Units Sold', 'Total Revenue', 'Total Profit'

]

# %%
columns = labels

# %% [markdown]
# Using Scikit Learn for ML Modeling

# %%
from sklearn.tree import DecisionTreeRegressor

#Define model. Specify a number for random_state to ensure same results each run
melb_model = DecisionTreeRegressor(random_state=1)   #DecisionTreeRegressor

melb_model.fit(X,y)

DecisionTreeRegressor(random_state=1)
# Out:
# DecisionTreeRegressor(random_state=1)

# %%
melb_model.predict(X.head())
# Out:
# array([668.27, 255.28, 421.89, 421.89, 205.7 ])

# %%
print('Making predictions for sales:')
print(X.head())
print('the prediction are')
print(melb_model.predict(X.head()))
print('My ML Model:)')
# Out:
# Making predictions for sales:
#     Price  Units Sold  Total Revenue  Total Profit
# 0  668.27        3604     2408445.08     597290.92
# 1  255.28        8435     2153286.80     808579.10
# 2  421.89        4848     2045322.72     277305.60
# 3  421.89        7225     3048155.25     413270.00
# 4  205.70        1975      406257.50     174965.25
# the prediction are
# [668.27 255.28 421.89 421.89 205.7 ]
# My ML Model:)

# %%
#From the predictions we can tell that price of a house in postcode 2607
# is almost double the price of houses in postcodes 2905&2906

# %% [markdown]
# Model Evaluation -MEA

# %%
from sklearn.metrics import mean_absolute_error

predicted_sales = melb_model.predict(X)
mean_absolute_error(y, predicted_sales)
# Out:
# 9.410454779867904e-12

# %%
#error is 9.41
#Our mean absolute error for the in-sample data is 9.41 dollars

# %%
from sklearn.model_selection import train_test_split

# %%
train_X, val_X, train_y, val_y = train_test_split(X, y, random_state = 1)

#Define model
melb_model = DecisionTreeRegressor(random_state=1)

#Fit model
melb_model.fit(train_X, train_y)
# Out:
# DecisionTreeRegressor(random_state=1)

# %%
val_predictions = melb_model.predict(val_X)
print(mean_absolute_error(val_y, val_predictions))
# Out:
# 9.353926486710407e-12

# %%
#Out-of-sample is 9.35 dollars
#Average price of item is roughly 265 dollars

#error is miniscule

# %% [markdown]
# Data Visualization

# %%
import seaborn as sns
import matplotlib.pyplot as plt
import matplotlib as mpl
import numpy as np

# Inline backend
# %matplotlib inline
mpl.style.use(['ggplot'])
import warnings
warnings.filterwarnings('ignore')

# %%
df.columns
# Out:
# Index(['Region', 'Country', 'Item Type', 'Sales Channel', 'Order Priority',
#        'Order Date', 'Order ID', 'Ship Date', 'Units Sold', 'Price',
#        'Unit Cost', 'Total Revenue', 'Total Cost', 'Total Profit'],
#       dtype='object')

# %%
sns.countplot(df['Price'])

# %%
df.head()
# Out:
#                Region   Country  ...  Total Cost Total Profit
# 0  Sub-Saharan Africa   Namibia  ...  1811154.16    597290.92
# 1              Europe   Iceland  ...  1344707.70    808579.10
# 2              Europe    Russia  ...  1768017.12    277305.60
# 3              Europe  Moldova   ...  2634885.25    413270.00
# 4              Europe     Malta  ...   231292.25    174965.25
#
# [5 rows x 14 columns]

# %%
df.plot(kind='line', figsize=(14, 8))

plt.title('price')
plt.xlabel('Value')

plt.show()

# %%
df.plot  (kind="hist")

# %%
df.plot (kind="area")

# %%
df.plot(kind='line', figsize=(14, 8))

plt.title('price')
plt.xlabel('value')


plt.show()
